# %%
import seaborn as sns
import pandas as pd

# %%
newd = pd.read_csv('out.csv')

# %%
newd.kmer7
# Out:
# 0         {'AATTAGT': 1, 'ATTAGTC': 1, 'TTAGTCA': 1, 'TA...
# 1         {'AATTAGT': 1, 'ATTAGTC': 1, 'TTAGTCA': 1, 'TA...
# 2         {'AATTAGT': 1, 'ATTAGTC': 1, 'TTAGTCA': 1, 'TA...
# 3         {'AATTAGT': 1, 'ATTAGTC': 1, 'TTAGTCA': 1, 'TA...
# 4         {'AATTAGT': 1, 'ATTAGTC': 1, 'TTAGTCA': 1, 'TA...
#                                 ...
# 205868    {'CCAGGAT': 1, 'CAGGATA': 1, 'AGGATAA': 1, 'GG...
# 205869    {'ACACAGC': 1, 'CACAGCA': 1, 'ACAGCAT': 1, 'CA...
# 205870    {'GGTTTTA': 1, 'GTTTTAT': 1, 'TTTTATG': 1, 'TT...
# 205871    {'ACATCTA': 1, 'CATCTAA': 1, 'ATCTAAG': 1, 'TC...
# 205872    {'AATTAGG': 1, 'ATTAGGG': 1, 'TTAGGGC': 1, 'TA...
# Name: kmer7, Length: 205873, dtype: object

# %%
aa = pd.read_csv('kmer4.csv')
bb = pd.read_csv('kmer5.csv')
cc = pd.read_csv('kmer6.csv')
dd = pd.read_csv('kmer7.csv')
ee = pd.read_csv('kmer8.csv')
ff = pd.read_csv('kmer9.csv')

# %%
aa.head()
# Out:
#    Unnamed: 0      target_gene  \
# 0           0  ENSG00000000460
# 1           1  ENSG00000000938
# 2           2  ENSG00000000971
# 3           3  ENSG00000001084
# 4           4  ENSG00000001167
#
#                                                kmer4  \
# 0  [{'AGCC': 4, 'GCCA': 3, 'CCAG': 5, 'CAGA': 2, ...
# 1  [{'ACTG': 4, 'CTGT': 2, 'TGTC': 2, 'GTCA': 2, ...
# 2  [{'GATT': 2, 'ATTG': 7, 'TTGT': 6, 'TGTA': 6, ...
# 3  [{'CAGA': 4, 'AGAG': 4, 'GAGC': 1, 'AGCA': 4, ...
# 4  [{'ATGC': 4, 'TGCT': 5, 'GCTT': 8, 'CTTT': 9, ...
#
#                                                  max  num       mean  \
# 0  {'TTCT': 68, 'CCAA': 68, 'GAAG': 66, 'AATT': 6...   68  44.666667
# 1  {'CCTG': 39, 'TCAG': 38, 'CAGG': 38, 'CTGG': 3...   39  27.136719
# 2  {'AATT': 44, 'AAAA': 44, 'TACA': 43, 'ACAT': 4...   44  29.141176
# 3  {'AGCT': 57, 'AAAG': 57, 'CAAA': 57, 'TTAA': 5...   57  39.433594
# 4  {'TGCT': 13, 'AAGG': 13, 'TCAA': 13, 'ATCA': 1...   13   8.738956
#
#    atleastTwo                                        common_keys  \
# 0         254                                   {'CCAA', 'TTCT'}
# 1         256                                           {'CCTG'}
# 2         254                                              set()
# 3         255                                              set()
# 4         239  {'AAGG', 'GGAA', 'TCAA', 'ATCA', 'TGCT', 'CTCA...
#
#    common_keys_size  size
# 0                 2    68
# 1                 1    39
# 2                 0    45
# 3                 0    60
# 4                 8    13

# %%
sns.scatterplot(x="size", y="common_keys_size", data=aa);

# %%
sns.scatterplot(x="size", y="common_keys_size", data=bb);

# %%
sns.scatterplot(x="size", y="common_keys_size", data=cc);

# %%
sns.scatterplot(x="size", y="common_keys_size", data=dd);

# %%
sns.scatterplot(x="size", y="common_keys_size", data=ee);

# %%
ff[ff.num ==  max(ff.num)  ]
# Out:
#       Unnamed: 0      target_gene  \
# 1081        1124  ENSG00000102904
# 3338        3474  ENSG00000141084
#
#                                                   kmer9 common_keys  \
# 1081  [{'ATGAGGACG': 1, 'TGAGGACGT': 1, 'GAGGACGTG':...       set()
# 3338  [{'ATGAGGACG': 1, 'TGAGGACGT': 1, 'GAGGACGTG':...       set()
#
#       common_keys_size  size  \
# 1081                 0   268
# 3338                 0   268
#
#                                                     max  num      mean  \
# 1081  {'TTGGGAGGC': 65, 'CCAGGCTGG': 58, 'GATTACAGG'...   65  5.091604
# 3338  {'TTGGGAGGC': 65, 'CCAGGCTGG': 58, 'GATTACAGG'...   65  5.091604
#
#       atleastTwo
# 1081       22474
# 3338       22474

# %%
dd[dd.common_keys_size==max(dd.common_keys_size)]
# Out:
#     Unnamed: 0      target_gene  \
# 48          50  ENSG00000006128
#
#                                                 kmer7  \
# 48  [{'CTTGAAA': 1, 'TTGAAAA': 1, 'TGAAAAT': 1, 'G...
#
#                                                   max  num  mean  atleastTwo  \
# 48  {'CTTGAAA': 2, 'TTGAAAA': 2, 'TGAAAAT': 2, 'GA...    2   2.0        1124
#
#                                           common_keys  common_keys_size  size
# 48  {'ACCACTG', 'GTTTCTC', 'CTGTTTA', 'GGCAAAG', '...              1124     2

# %%
dd[dd['size']==5].common_keys_size.mean()
# Out:
# 0.009259259259259259

# %% [markdown]
# num is frequency of maximum repeated kmer

# %%
sns.scatterplot(x="size", y="num", data=aa);

# %%
sns.scatterplot(x="size", y="num", data=bb);

# %%
sns.scatterplot(x="size", y="num", data=cc);

# %%
sns.scatterplot(x="size", y="num", data=dd);

# %%
sns.scatterplot(x="size", y="num", data=ee);

# %%
sns.scatterplot(x="size", y="num", data=ff);
